# %%
import numpy as np
import matplotlib.pyplot as plt
data_5 = np.load("For_Panya_Kappa_is_15.3,Resonator_Population_65, Qubit_levels_20.npz")
t_5 = data_5["t"]
n_g_5 = data_5["n_g"]
n_e_5 = data_5["n_e"]
leak_g_5 = data_5["leak_g"]
leak_e_5 = data_5["leak_e"]
assignment_error_5 = data_5["assignment_error"]
snr_5 = data_5["snr"]
plt.plot(t_5, n_e_5, label = "kappa = 15.3 MHz", color = "r", linewidth = "2.5")
plt.grid()
plt.legend()
plt.axvline(100,color="b", linestyle="--", alpha=0.5 )
plt.axvline(300,color="g", linestyle="--", alpha=0.5)
plt.title("Resonator levels 65 and Qubit levels 22 vs 19")
plt.savefig('leakage_population_combined_25_22_and_19_kappa_10MHz.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
data_5 = np.load("For_Panya_Kappa_is_15.3,Resonator_Population_65, Qubit_levels_20.npz")
data_25 =  np.load("600_19_Kappa_is_2.5,Resonator_Population_60, Qubit_levels_19.npz")
data_10 =  np.load("2Kappa_is_10.0,Resonator_Population_65, Qubit_levels_22.npz")
data_10_19 = np.load("19Kappa_is_10.0,Resonator_Population_65, Qubit_levels_19.npz")
data_10_25 = np.load("25Kappa_is_10.0,Resonator_Population_65, Qubit_levels_25.npz")

# %%
np.load("Kappa_is_10.0,Resonator_Population_65, Qubit_levels_20.npz")
print(data_10)
# Out:
# NpzFile '2Kappa_is_10.0,Resonator_Population_65, Qubit_levels_22.npz' with keys: t, n_g, n_e, leak_g, leak_e...

# %%
print(data_5)
# Out:
# NpzFile 'For_Panya_Kappa_is_15.3,Resonator_Population_65, Qubit_levels_20.npz' with keys: t, n_g, n_e, leak_g, leak_e...

# %%
# Out:
# NpzFile 'For_Panya_Kappa_is_15.3,Resonator_Population_65, Qubit_levels_20.npz' with keys: t, n_g, n_e, leak_g, leak_e...

# %%
t_25 = data_25["t"]
n_g_25 = data_25["n_g"]
n_e_25 = data_25["n_e"]
leak_g_25 = data_25["leak_g"]
leak_e_25 = data_25["leak_e"]
assignment_error_25 = data_25["assignment_error"]
snr_25 = data_25["snr"]

# %%
t_5 = data_5["t"]
n_g_5 = data_5["n_g"]
n_e_5 = data_5["n_e"]
leak_g_5 = data_5["leak_g"]
leak_e_5 = data_5["leak_e"]
assignment_error_5 = data_5["assignment_error"]
snr_5 = data_5["snr"]

# %%
t_10 = data_10["t"]
n_g_10 = data_10["n_g"]
n_e_10 = data_10["n_e"]
leak_g_10 = data_10["leak_g"]
leak_e_10 = data_10["leak_e"]
assignment_error_10 = data_10["assignment_error"]
snr_10 = data_10["snr"]

# %%
t_10_19 = data_10_19["t"]
n_g_10_19 = data_10_19["n_g"]
n_e_10_19 = data_10_19["n_e"]
leak_g_10_19 = data_10_19["leak_g"]
leak_e_10_19 = data_10_19["leak_e"]
assignment_error_10_19 = data_10_19["assignment_error"]
snr_10_19 = data_10_19["snr"]

# %%
t_10_25 = data_10_25["t"]
n_g_10_25 = data_10_25["n_g"]
n_e_10_25 = data_10_25["n_e"]
leak_g_10_25 = data_10_25["leak_g"]
leak_e_10_25 = data_10_25["leak_e"]
assignment_error_10_25 = data_10_25["assignment_error"]
snr_10_19 = data_10_25["snr"]

# %%
#plt.plot(t,n_e)
# plt.plot(t_5, n_e_5, label = "kappa = 2.5 MHz", color = "r", linewidth = "2.5")
plt.plot(t_5,leak_e_5, label = "kappa = 5 MHz" , color = "deeppink", linewidth = "2.5")
# plt.plot(t_10,leak_e_10, label = "kappa = 10 MHz 22 levels", color = "r" , linewidth = "2.5" )
# plt.plot(t_10_19,leak_e_10_19, label = "kappa = 10 MHz 19 levels", color = "hotpink" , linewidth = "2.5" )
# plt.plot(t_10_25,leak_e_10_25, label = "kappa = 10 MHz 25 levels", color = "g" , linewidth = "2.5" )

plt.yscale("log")
plt.ylim(1e-2, 1e0)
plt.grid()
plt.legend()
plt.axvline(100,color="b", linestyle="--", alpha=0.5 )
plt.axvline(300,color="g", linestyle="--", alpha=0.5)
plt.title("Resonator levels 65 and Qubit levels 22 vs 19")
plt.savefig('leakage_population_combined_25_22_and_19_kappa_10MHz.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(t_5, n_e_5, label = "kappa = 2.5 MHz", color = "r", linewidth = "2.5")
# plt.plot(t_5,n_e_5, label = "kappa = 5 MHz", color = "deeppink", linewidth = "2.5")
# plt.plot(t_10,n_e_10, label = "kappa = 10 MHz ", color = "r", linewidth = "2.5" )
# plt.plot(t_10_19,n_e_10_19, label = "kappa = 10 MHz 19 levels", color = "b", linewidth = "2.5" )
# plt.plot(t_10_25,n_e_10_25, label = "kappa = 10 MHz 25 levels", color = "g" , linewidth = "2.5" )
#plt.ylim(1e-2, 1e0)
plt.grid()
plt.legend()
#plt.vlines(t_5, 100, 300)
plt.axvline(100,color="b", linestyle="--", alpha=0.5 )
plt.axvline(300,color="g", linestyle="--", alpha=0.5)
plt.title("Resonator levels 65 and Qubit levels 26")
#np.savez(f"2Kappa_is_{kappa},Resonator_Population_{res_dim}, Qubit_levels_{qubit_levels}", t= t, n_g = n_g, n_e = n_e, leak_g = leak_g, leak_e = leak_e, assignment_error = assignment_error, snr =snr)
plt.savefig('resonator_population_combined_19,22,25.png', dpi=300, bbox_inches='tight')
plt.show(block=True)

# %%
x = 300/(450/1000)
x
# Out:
# 666.6666666666666

# %%
print(leak_e_25[600:])
# Out:
# [0.98946332 0.98220419 0.98835622 0.98688446 0.98335589 0.98951231
#  0.98318694 0.98675602 0.98812407 0.98218805 0.98898857 0.98454524
#  0.98499391 0.98866052 0.98194192 0.9878734  0.98589561 0.98317799
#  0.98867622 0.98242368 0.98633812 0.98697711 0.98181415 0.9881895
#  0.98356026 0.98439282 0.98755774 0.98117684 0.98703777 0.98458814
#  0.9823925  0.9875867  0.98117584 0.98544994 0.98532621 0.98070563
#  0.98696762 0.98174575 0.9832177  0.98571806 0.97955427 0.98552834
#  0.98244441 0.98080119 0.98547386 0.97884756 0.98348241 0.9828582
#  0.97824901 0.98453642 0.97860379 0.98060811 0.98270953 0.97603671
#  0.98256425 0.97830482 0.97708117 0.98170428 0.97404574 0.97944553
#  0.97767786 0.97306794 0.97963247 0.97217452 0.97498472 0.97623538
#  0.96868545 0.97604608 0.96998664 0.96910003 0.97347435 0.96394563
#  0.97050404 0.96697765 0.96176844 0.96888054 0.95873425 0.96261368
#  0.96264047 0.95312432 0.96189068 0.95270236 0.95207774 0.95631235
# ...

# %%
mask = t_10[667:] > 300
print(mask)
print(t_10[667:])
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %%
print(leak_e_10[667:])
# Out:
# [0.96315094 0.96978809 0.9535745  0.97523257 0.95007301 0.97300345
#  0.95333935 0.96982034 0.96258281 0.95988095 0.96629373 0.95411154
#  0.97049583 0.9534982  0.9692676  0.95531434 0.96458719 0.95889465
#  0.95842351 0.95815306 0.9504826  0.9541888  0.94293956 0.94643065
#  0.930636   0.93180322 0.9126194  0.91199897 0.88882254 0.88389954
#  0.86011128 0.8466192  0.82890565 0.79981885 0.79244764 0.74634652
#  0.75048523 0.69393534 0.70015879 0.6475206  0.64142098 0.60906897
#  0.57964057 0.57342123 0.52003657 0.53901591 0.47134813 0.50150047
#  0.4390081  0.45409594 0.42239275 0.41051777 0.40869681 0.37100953
#  0.39664332 0.3408668  0.38306882 0.32554638 0.35532033 0.32435223
#  0.32895155 0.32500459 0.30425159 0.3237378  0.28335234 0.32124346
#  0.27278412 0.30623292 0.27298306 0.28632807 0.27698262 0.2676863
#  0.27772967 0.24991786 0.27785155 0.23867312 0.26964607 0.23624196
#  0.2535136  0.23895963 0.23758264 0.24051094 0.22170983 0.2404238
# ...

# %%
mask = t_10[667:] > 300  # after drive off
log_leak_10 = np.log(leak_e_10[667:])
log_n = np.log(n_e_10[667:])
log_leak_5 = np.log(leak_e_5[600:])
log_n_5 = np.log(n_e_10[600:])
log_leak_25 = np.log(leak_e_25[600:])
log_n_25 = np.log(n_e_10[600:])

# fit slopes
slope_leak_10 = np.polyfit(t_10[667:], log_leak_10, 1)
slope_n_10 = np.polyfit(t_10[667:], log_n, 1)
slope_leak_5 = np.polyfit(t_5[600:], log_leak_5, 1)
slope_n_5 = np.polyfit(t_5[600:], log_n_5, 1)
slope_leak_25 = np.polyfit(t_25[600:], log_leak_25, 1)
slope_n_25 = np.polyfit(t_25[600:], log_n_25, 1)
# print(slope_leak)
# print(slope_n)
print("leakage decay rate:", -slope_leak_10, " vs kappa:",  " vs resonator decay rate:", -slope_n_10)
plt.plot(slope_leak_10, slope_n_10, label = "10")
plt.plot(slope_leak_5, slope_n_5, label ="5")
# plt.plot(slope_leak_25, slope_n_25, label = "25")
#plt.plot()
plt.xlabel("Resonator decay SLOPE")
plt.ylabel("LEAKAGE decay SLOPE")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# leakage decay rate: [ 0.01517262 -3.89340408]  vs kappa:  vs resonator decay rate: [  0.06173535 -22.18908822]

# %%
from parameters import load_json

# Load the JSON
device, pulse, simulation = load_json("device_parameter.json")

# %%
g_eff = device.g * abs(device.n_matrix[1, 12])   # or whichever level pair dominates the crossing
Delta = device.omega_levels[1] - device.omega_levels[0] - device.omega_r
ratio = (g_eff / Delta)**2
print(ratio, "vs observed slope ~5.6")
# Out:
# 9.516165340218117e-09 vs observed slope ~5.6

# %%
import numpy as np

# %%
data1 = np.load("Full_phi.npy")
data2 = np.load("Full_nue.npy")

# %%
omega_d_list = np.arange(8.5, 9.5, 0.001)

# %%
len(omega_d_list)
# Out:
# 1000

# %%
import matplotlib.pyplot as plt

# %%
for plot in range(0, 3):

    if plot == 0:
        cmap = "Reds"
    elif plot == 1:
        cmap =  "Greens"
    else:
        cmap =  "Blues"

    x_1 = np.zeros((len(omega_d_list), 50), dtype = float)
    xx_1 = np.zeros((len(omega_d_list), 50), dtype = float)

    for i in range(0,len(omega_d_list)):
        for j in range(0,50):
            l = data1[i][plot][j]
            x_1[i][j] = l
            m = data2[i][plot][j]
            xx_1[i][j] = m


    nbar_vals = np.arange(0, 50)  
    floor = 1e-20   # avoid log(0)


    log_n_phi = np.log(x_1.T )
    log_n_nue  = np.log(xx_1.T)


    cmin=10**(-4)
    cmid=1
    cmax=np.max(np.transpose(x_1))
    print(cmax)
    len(omega_d_list)
    omega_d_list
    fig, axes = plt.subplots(2, 1, figsize=(3, 9), sharex=True)

    im0 = axes[0].pcolormesh(omega_d_list, nbar_vals, log_n_phi, shading = 'auto' , cmap=cmap)#, norm = colors.LogNorm(vmin = 1e-4, vmax = 17))
    axes[0].set_ylabel(r'$\bar{n}_r$')
    axes[0].set_title(r'$\log\langle n_\phi \rangle$')
    # axes[0].set_xticks([8.5 , 8.55, 8.6 , 8.65, 8.7 , 8.75, 8.8 , 8.85, 8.9 , 8.95, 9.  ,
    #     9.05, 9.1 , 9.15, 9.2 , 9.25, 9.3 , 9.35, 9.4 , 9.45, 9.5 ])
    axes[0].set_xticks([8.5, 9.0, 9.5])
    cbar = plt.colorbar(im0)
    cbar.ax.set_yticks([np.log(cmin),np.log(cmid),np.log(cmax)],[r"$10^{-4}$",r"$1$",rf"${np.round(cmax)}$"],fontsize=10)  #{np.round(cmax)}



    cmin=10**(-4)
    cmid=1
    cmax=np.max(np.transpose(xx_1))
    print(cmax)



    im1 = axes[1].pcolormesh(omega_d_list, nbar_vals, log_n_nue ,
                            shading='auto', cmap= cmap)#, norm =2colors.LogNorm(vmin = 1e-4, vmax = 1))
    axes[1].set_xlabel(r'$\omega_d/2\pi$ (GHz)')
    axes[1].set_ylabel(r'$\bar{n}_r$')
    axes[1].set_title(r'$\log\langle n_\mu \rangle$')
    #axes[1].set_xticks([8.5 , 8.55, 8.6 , 8.65, 8.7 , 8.75, 8.8 , 8.85, 8.9 , 8.95, 9.  ,
    #        9.05, 9.1 , 9.15, 9.2 , 9.25, 9.3 , 9.35, 9.4 , 9.45, 9.5 ])
    axes[1].set_xticks([8.5, 9.0, 9.5])
    #fig.colorbar(im1)
    cbar = plt.colorbar(im1)
    cbar.ax.set_yticks([np.log(cmin),np.log(cmax)],[r"$10^{-4}$",rf"${np.round(cmax)}$"],fontsize=10)
    #cbar.set_ticklabels([r"$10^{-4}$","1"])
    filename = f"floquet_{cmap}.pdf"

    fig.savefig(filename, bbox_inches='tight')
    print(f"Figure saved as: {filename}")
    plt.tight_layout()
    plt.show()
# Out:
# 12.667494773864746
# 1.5720319747924805
# Figure saved as: floquet_Reds.pdf
# 16.718841552734375
# 1.0871049165725708
# Figure saved as: floquet_Greens.pdf
# 14.008241653442383
# 1.9657142162322998
# Figure saved as: floquet_Blues.pdf
